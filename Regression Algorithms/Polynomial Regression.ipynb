# %% [markdown]
# ***

# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# ***

# %% [markdown]
# ### 👉🏾 Data Preprocessing

# %% [markdown]
# #### ☑️ Importing libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:/Users/HP Elitebook/OneDrive/Bureau/HOMEWORKS/ML_BOOTCAMP/Machine Learning A-Z (Codes and Datasets)/Part 2 - Regression/Section 6 - Polynomial Regression/Python/Position_Salaries.csv')
data
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %% [markdown]
# #### ☑️ Creating and Reshaping Variables

# %%
x = data.iloc[:, 1].values
y = data.iloc[:, 2].values
x = x[:, np.newaxis]

# %% [markdown]
# #### ☑️ Particularity

# %% [markdown]
# This time there is no missing or invalid data so we skip imputation part.<br> Also we've got a small dataset so no need to split the dataset. We will train our model on the wole dataset as we need maximum information for carrying out the model.

# %% [markdown]
# ### 👉🏾 Training on the whole dataset

# %% [markdown]
# #### ☑️ Linear Regression

# %%
from sklearn.linear_model import LinearRegression
l_reg = LinearRegression()
l_reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# #### ☑️ Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
p_reg = PolynomialFeatures( degree = 2)    # Creating Polyn.features with 2 degrees.
x_poly = p_reg.fit_transform(x)            # Transforming the independant variable 'x' into a polynomial features
l_reg2 = LinearRegression()
l_reg2.fit(x_poly, y)                      # Fitting a new linear_reg model with our polynomial ind_var 'x_poly'
# Out:
# LinearRegression()

# %% [markdown]
# ### 👉🏾 Visualization

# %%
plt.figure(figsize = (12,5))

plt.subplot(1,2,1)
plt.scatter(x, y, c = 'red')
plt.plot(x, l_reg.predict(x), c = 'blue')
plt.title('Linear Regression Version')
plt.xlabel('Salary level')
plt.ylabel('Salaries')

plt.subplot(1,2,2)
plt.scatter(x, y, c = 'red')
plt.plot(x, l_reg2.predict(x_poly), c = 'blue')
plt.title('Polynomial Regression Version')
plt.xlabel('Salary level')
plt.ylabel('Salaries')
# Out:
# Text(0, 0.5, 'Salaries')

# %% [markdown]
# ### 👉🏾 Training Polynomial Regression with Higher Degree For much Accuracy

# %% [markdown]
# #### ☑️ Fitting the model

# %%
p_reg2 = PolynomialFeatures( degree = 4)    # Creating Polyn.features with 4 degrees.
x_poly2 = p_reg2.fit_transform(x)            # Transforming the independant variable 'x' into a polynomial features
l_reg3 = LinearRegression()
l_reg3.fit(x_poly2, y)                      # Fitting a new linear_reg model with our polynomial ind_var 'x_poly'
# Out:
# LinearRegression()

# %% [markdown]
# #### ☑️ Visualization

# %%
plt.figure(figsize = (12,6))

plt.subplot(1,2,1)
plt.scatter(x, y, c = 'red')
plt.plot(x, l_reg2.predict(x_poly), c = 'blue')
plt.title('Polynomial Regression Version - 2 degrees')
plt.xlabel('Salary level')
plt.ylabel('Salaries')

plt.subplot(1,2,2)
plt.scatter(x, y, c = 'red')
plt.plot(x, l_reg3.predict(x_poly2), c = 'blue')
plt.title('Polynomial Regression Version - 4 degrees')
plt.xlabel('Salary level')
plt.ylabel('Salaries')
# Out:
# Text(0, 0.5, 'Salaries')

# %% [markdown]
# ### 👉🏾 Predictions

# %% [markdown]
# #### ☑️ Linear Regression

# %%
np.set_printoptions(precision = 2)
x_ = 6.5
y_lin = l_reg.predict([[6.5]])
y_lin
# Out:
# array([330378.79])

# %% [markdown]
# #### ☑️ Polynomial Regression

# %% [markdown]
# ##### 1️⃣ Degree 2

# %%
x_ = p_reg.fit_transform([[6.5]])    # Transforming the variable into Polynomial Features degree 2
y_pol1 = l_reg2.predict(x_)
y_pol1
# Out:
# array([189498.11])

# %% [markdown]
# ##### 2️⃣ Degree 4

# %%
x_ = p_reg2.fit_transform([[6.5]])  # Transforming again into PF degree 4
y_pol2 = l_reg3.predict(x_)
y_pol2
# Out:
# array([158862.45])

# %% [markdown]
# <div class = 'alert alert-block alert-warning'>
#    💁🏾‍♂️ So before forcasting a value with polynomial regression we must first of all transform it in polynomial feature or it won't work. </div>

# %% [markdown]
# #### ☑️ Visualization

# %%
dic = {
    'Lin_pred':y_lin,
    'Pol_pred_1': y_pol1,
    'Pol_pred_2': y_pol2
}
a = pd.DataFrame(dic)
a
# Out:
#         Lin_pred     Pol_pred_1     Pol_pred_2
# 0  330378.787879  189498.106061  158862.452652

# %% [markdown]
# ***

# %% [markdown]
# ![AllDone%E6%90%9E%E5%AE%9AGIF.gif](attachment:AllDone%E6%90%9E%E5%AE%9AGIF.gif)
