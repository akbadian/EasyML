# %% [markdown]
# ***

# %% [markdown]
# ## 1️⃣ Simple Linear Regression

# %% [markdown]
# ***

# %% [markdown]
# **Aim:** Trying to explain the salary level by the years of experience <code> Salary = b0 + b1*Experience</code>.

# %% [markdown]
# ***

# %% [markdown]
# #### ☑️ Importing Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 👉Data Preprocessing

# %%
df = pd.read_csv('C:/Users/HP Elitebook/OneDrive/Bureau/HOMEWORKS/ML_BOOTCAMP/Machine Learning A-Z (Codes and Datasets)/Part 2 - Regression/Section 4 - Simple Linear Regression/Python/Salary_Data.csv')
df.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
x = df.iloc[:,0].values
x = x[:,np.newaxis]
y = df.iloc[:,1].values
y = y[:,np.newaxis]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ### 👉 Training SLRM on the training sets

# %% [markdown]
# #### ☑️ Fitting the model

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### ☑️ Predictions

# %%
y_pred = regressor.predict(x_test)

# %% [markdown]
# #### ☑️ Visualization of Training Sets Results

# %%
plt.scatter(x_train, y_train, color = 'green')
plt.plot(x_train, regressor.predict(x_train)) # Adjust. line plotted with '''x_train & predict(x_train)'''
plt.legend()
plt.xlabel('Years of Exp.')
plt.ylabel('Salary Level')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #### ☑️ Visualization of Testing Sets Results

# %%
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_train, regressor.predict(x_train), color = 'darkgrey') # Adjust. line again !!!
plt.xlabel('Years of Exp.')
plt.ylabel('Salary Level')
plt.show()

# %% [markdown]
# #### ☑️ Predictions of the salary of an employee with 20 years of experience

# %%
y_20 = regressor.predict([[20]])
print('His salary is {}'.format(y_20))
# Out:
# His salary is [[213031.60168521]]

# %% [markdown]
# <div class = 'alert alert-block alert-info' > 💁🏾‍♂️ We put the years of experience between double brackets [[]] because the predict function only accept 2D-array.</div>

# %% [markdown]
# ### 👉🏾👉🏾 Final Linear Equation

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [[9312.57512673]]
# [26780.09915063]

# %% [markdown]
# 👉🏾 So the equation for our linear model is : <br> <code> Salary = 26780.09915063 + 9312.57512673 * Exp. </code>

# %% [markdown]
# ![SadNoWayGIF.gif](attachment:SadNoWayGIF.gif)
